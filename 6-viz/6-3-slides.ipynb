# %% [markdown]
# # 6-3: Visualizations: maps
#
# - mapping with folium and geopandas

# %% [markdown]
# ## Mapping
#
# - Mapping is a powerful way to visualize data. You can place points on a map, draw lines, and shade areas.
#
# - In this lesson, we will use the `folium` and `geopandas` libraries to create maps.
#
#
# ## Map Visualizations with Folium
#
# To create map visualizations, we will use the Folium, which is a Python wrapper for the Leaflet.js library.
#
# https://python-visualization.github.io/folium/latest/
#
# Folium uses https://www.openstreetmap.org/ for drawing maps. Its a free/open source alternative to a service like Google Maps.

# %%
import folium
JMA = (43.0362, -76.1363)
map1 = folium.Map(location=JMA, zoom_start=18)
jma_marker = folium.Marker(JMA, popup='JMA Wireless Dome', tooltip="JMA").add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a87fbb01af16af235b13df4d79ebd9d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a87fbb01af16af235b13df4d79ebd9d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a87fbb01af16af235b13df4d79ebd9d1 = L.map(
#                 &quot;map_a87fbb01af16af235b13df4d79ebd9d1&quot;,
#                 {
#                     center: [43.0362, -76.1363],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d096b10d371240258c0c7388438d5b91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d096b10d371240258c0c7388438d5b91.addTo(map_a87fbb01af16af235b13df4d79ebd9d1);
#
#
#             var marker_51c6da89332e91bad76d238db5e67668 = L.marker(
#                 [43.0362, -76.1363],
#                 {}
#             ).addTo(map_a87fbb01af16af235b13df4d79ebd9d1);
#
#
#         var popup_9317c2ec31d6878821ecf6f2aef44cfd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4130a25e200c28b64fb2ca28e99648dd = $(`&lt;div id=&quot;html_4130a25e200c28b64fb2ca28e99648dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JMA Wireless Dome&lt;/div&gt;`)[0];
#                 popup_9317c2ec31d6878821ecf6f2aef44cfd.setContent(html_4130a25e200c28b64fb2ca28e99648dd);
#
#
#
#         marker_51c6da89332e91bad76d238db5e67668.bindPopup(popup_9317c2ec31d6878821ecf6f2aef44cfd)
#         ;
#
#
#
#
#             marker_51c6da89332e91bad76d238db5e67668.bindTooltip(
#                 `&lt;div&gt;
#                      JMA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Folium and Streamlit
#
# To display folium maps to display in Streamlit, you need to use the `streamlit_folium` module.
#
# This module has two functions:
#
# - `folium_static` is used to display the map only.
# - `st_folium` is use to display the map and return data while the user interacts with the map.
#
# See:
# `6-3-st-folium.py`

# %% [markdown]
# ### Map Markers Colors and Icons
#
# Through the `icon` named argument you can assign an icon to the popup. You must create a `folium.Icon()` to assign a custom icon. There are three named arguments:
#
# `color=` the color of the marker
# `icon_color=` the color of the icon on the marker
# `icon=` the name of the icon.
#
#
# Valid colors are: `['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']`
#
# Valid icons can be found here: https://fontawesome.com/v4/icons/ Your mileage may vary here as not all the icons listed are available.

# %% [markdown]
# ### Mapping a dataframe
#
# To map a dataframe:
#
# 1. we need coordinates
# 2. we need to use loop over the data, creating a marker for each row

# %%
import pandas as pd
classesdf = pd.read_csv("https://raw.githubusercontent.com/mafudge/datasets/master/delimited/class-schedule.csv")
schine = (43.03986, -76.13375)
m = folium.Map(location=schine, zoom_start=17)

for index, row in classesdf.iterrows():
    text = f"{row['Course']} {row['Day']} {row['Time']} {row['Building']}"
    dd = (row['Lat'], row['Lon'])
    if row['Day'] == "TuTh":
        markercolor = 'orange'
    else:
        markercolor = 'darkblue'
    marker = folium.Marker(location=dd, popup=text, icon = folium.Icon(color = markercolor, icon="globe"))
    marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_470420553f0fed6a305470798e9ab71b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_470420553f0fed6a305470798e9ab71b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_470420553f0fed6a305470798e9ab71b = L.map(
#                 &quot;map_470420553f0fed6a305470798e9ab71b&quot;,
#                 {
#                     center: [43.03986, -76.13375],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90759eea7694c31098b4ae1f2672dff0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_90759eea7694c31098b4ae1f2672dff0.addTo(map_470420553f0fed6a305470798e9ab71b);
#
#
#             var marker_d585cc47469b66da9ada6cf8fd6e7945 = L.marker(
#                 [43.03819, -76.13413],
#                 {}
#             ).addTo(map_470420553f0fed6a305470798e9ab71b);
#
#
#             var icon_b1455b6e14360d9be1576ccdc4e000a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d585cc47469b66da9ada6cf8fd6e7945.setIcon(icon_b1455b6e14360d9be1576ccdc4e000a6);
#
#
#         var popup_db169ad07037a8f5b06e14131dbc34a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23028e10a796227e9ba1e86c60eb980d = $(`&lt;div id=&quot;html_23028e10a796227e9ba1e86c60eb980d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IST256 M 3:45pm HBC&lt;/div&gt;`)[0];
#                 popup_db169ad07037a8f5b06e14131dbc34a6.setContent(html_23028e10a796227e9ba1e86c60eb980d);
#
#
#
#         marker_d585cc47469b66da9ada6cf8fd6e7945.bindPopup(popup_db169ad07037a8f5b06e14131dbc34a6)
#         ;
#
#
#
#
#             var marker_c1f034122b84dee258db0df48f4e3b9d = L.marker(
#                 [43.03674, -76.1332],
#                 {}
#             ).addTo(map_470420553f0fed6a305470798e9ab71b);
#
#
#             var icon_ac580fd1fa55bacdc20c75f47ccb79aa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c1f034122b84dee258db0df48f4e3b9d.setIcon(icon_ac580fd1fa55bacdc20c75f47ccb79aa);
#
#
#         var popup_b47ddf0e24674c432a7dff3fd19eb9db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c40fe385a09fa39124ba9fdee130feff = $(`&lt;div id=&quot;html_c40fe385a09fa39124ba9fdee130feff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MAT221 TuTh 12:45pm Bowne&lt;/div&gt;`)[0];
#                 popup_b47ddf0e24674c432a7dff3fd19eb9db.setContent(html_c40fe385a09fa39124ba9fdee130feff);
#
#
#
#         marker_c1f034122b84dee258db0df48f4e3b9d.bindPopup(popup_b47ddf0e24674c432a7dff3fd19eb9db)
#         ;
#
#
#
#
#             var marker_0ae3ae5255536dcf349959b870b12ac8 = L.marker(
#                 [43.03852, -76.13676],
#                 {}
#             ).addTo(map_470420553f0fed6a305470798e9ab71b);
#
#
#             var icon_a00db7920de850efb037885869a35d82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0ae3ae5255536dcf349959b870b12ac8.setIcon(icon_a00db7920de850efb037885869a35d82);
#
#
#         var popup_f228c894b69d79b55531dbedb56b6be4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_784122b414ceb63dbca88ae915096a14 = $(`&lt;div id=&quot;html_784122b414ceb63dbca88ae915096a14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WRT206 MW 9:20am Crouse&lt;/div&gt;`)[0];
#                 popup_f228c894b69d79b55531dbedb56b6be4.setContent(html_784122b414ceb63dbca88ae915096a14);
#
#
#
#         marker_0ae3ae5255536dcf349959b870b12ac8.bindPopup(popup_f228c894b69d79b55531dbedb56b6be4)
#         ;
#
#
#
#
#             var marker_9fc23dd9ee05dda283ef44f40e4dc383 = L.marker(
#                 [43.0402, -76.13521],
#                 {}
#             ).addTo(map_470420553f0fed6a305470798e9ab71b);
#
#
#             var icon_710cea0a58c42f88db68a13d3b57c579 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;wh

# %% [markdown]
# ## Challenge 6-3-1
#
# Streamlit version of Parkmagic!
#
# Load in the `final_cuse_parking_violations.csv` in the `data` folder and create a map of the parking violations in Syracuse.
#
# - drop rows without a latitude and longitude
# - provide a dropdown to select the status of the violation
# - place pins on the map with the street name and the violation description
# - color code the pins based on day of the week
# - to make the map more readable take a random sample of 50 rows from the dataframe

# %% [markdown]
# ## Geopandas
#
# Geopandas is a library that extends the Pandas library to work with geospatial data. It is built on top of the Shapely, Fiona, and Matplotlib libraries.
#
# https://geopandas.org/
#
# Geopandas can read and write data in many formats, including shapefiles, GeoJSON, and PostGIS. It can also display data on a map.
#
# Geopandas adds a `geometry` column to the dataframe. This column contains the geometry of the object. The geometry can be a POINT, LINE, or PLOYGON.
#
# Geopandas as a built in `explore()` function to display the data on a map.

# %%
import folium
import geopandas as gpd
schine = (43.03986, -76.13375)
map = folium.Map(location=schine, zoom_start=17)
classesdf = pd.read_csv("https://raw.githubusercontent.com/mafudge/datasets/master/delimited/class-schedule.csv")
gdf = gpd.GeoDataFrame(classesdf, geometry=gpd.points_from_xy(classesdf['Lon'], classesdf['Lat']))
gdf
# Out:
#    Course   Day     Time Building     Room       Lat       Lon  \
# 0  IST256     M   3:45pm      HBC  Gifford  43.03819 -76.13413
# 1  MAT221  TuTh  12:45pm    Bowne      104  43.03674 -76.13320
# 2  WRT206    MW   9:20am   Crouse      111  43.03852 -76.13676
# 3  COM222  TuTh   9:20am    NH II      232  43.04020 -76.13521
# 4  IST343    MW   2:15pm    Hinds      243  43.03834 -76.13364
#
#                      geometry
# 0  POINT (-76.13413 43.03819)
# 1   POINT (-76.1332 43.03674)
# 2  POINT (-76.13676 43.03852)
# 3   POINT (-76.13521 43.0402)
# 4  POINT (-76.13364 43.03834)

# %%
map_out = gdf.explore(m=map, marker_type="marker")
map_out
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e2372fe0b1e1dadb45c2015ba8e77cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e2372fe0b1e1dadb45c2015ba8e77cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e2372fe0b1e1dadb45c2015ba8e77cf = L.map(
#                 &quot;map_1e2372fe0b1e1dadb45c2015ba8e77cf&quot;,
#                 {
#                     center: [43.03986, -76.13375],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5579ffe167556032e4294718ed7257e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5579ffe167556032e4294718ed7257e6.addTo(map_1e2372fe0b1e1dadb45c2015ba8e77cf);
#
#
#         function geo_json_36ddca7f3c4e0bf664c860decb8ca868_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_36ddca7f3c4e0bf664c860decb8ca868_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_36ddca7f3c4e0bf664c860decb8ca868_pointToLayer(feature, latlng) {
#             var opts = {&quot;fill&quot;: true, &quot;radius&quot;: 2};
#
#             let style = geo_json_36ddca7f3c4e0bf664c860decb8ca868_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_36ddca7f3c4e0bf664c860decb8ca868_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_36ddca7f3c4e0bf664c860decb8ca868.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_36ddca7f3c4e0bf664c860decb8ca868_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_36ddca7f3c4e0bf664c860decb8ca868 = L.geoJson(null, {
#                 onEachFeature: geo_json_36ddca7f3c4e0bf664c860decb8ca868_onEachFeature,
#
#                 style: geo_json_36ddca7f3c4e0bf664c860decb8ca868_styler,
#                 pointToLayer: geo_json_36ddca7f3c4e0bf664c860decb8ca868_pointToLayer,
#         });
#
#         function geo_json_36ddca7f3c4e0bf664c860decb8ca868_add (data) {
#             geo_json_36ddca7f3c4e0bf664c860decb8ca868
#                 .addData(data);
#         }
#             geo_json_36ddca7f3c4e0bf664c860decb8ca868_add({&quot;bbox&quot;: [-76.13676, 43.03674, -76.1332, 43.0402], &quot;features&quot;: [{&quot;bbox&quot;: [-76.13413, 43.03819, -76.13413, 43.03819], &quot;geometry&quot;: {&quot;coordinates&quot;: [-76.13413, 43.03819], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Building&quot;: &quot;HBC&quot;, &quot;Course&quot;: &quot;IST256&quot;, &quot;Day&quot;: &quot;M&quot;, &quot;Lat&quot;: 43.03819, &quot;Lon&quot;: -76.13413, &quot;Room&quot;: &quot;Gifford&quot;, &quot;Time&quot;: &quot;3:45pm&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-76.1332, 43.03674, -76.1332, 43.03674], &quot;geometry&quot;: {&quot;coordinates&quot;: [-76.1332, 43.03674], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;Building&quot;: &quot;Bowne&quot;, &quot;Course&quot;: &quot;MAT221&quot;, &quot;Day&quot;: &quot;TuTh&quot;, &quot;Lat&quot;: 43.03674, &quot;Lon&quot;: -76.1332, &quot;Room&quot;: &quot;104&quot;, &quot;Time&quot;: &quot;12:45pm&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-76.13676, 43.03852, -76.13676, 43.03852], &quot;geometry&quot;: {&quot;coordinates&quot;: [-76.13676, 43.03852], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;Building&quot;: &quot;Crouse&quot;, &quot;Course&quot;: &quot;WRT206&quot;, &quot;Day&quot;: &quot;MW&quot;, &quot;Lat&quot;: 43.03852,

# %% [markdown]
# ## Choropleth Maps in Geopandas
#
# A choropleth map is a map that uses shading to represent the value of a variable. The shading can be based on a single value or a range of values.
#
# Choropleths maps require a GeoDataFrame with a geometry column. The geometry column contains the shapes that will be displayed on the map.

# %%
from matplotlib import colormaps
print(list(colormaps))
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 'Greens_r', 'Greys_r', 'OrRd_r', 'Oranges_r', 'PRGn_r', 'PiYG_r', 'PuBu_r', 'PuBuGn_r', 'PuOr_r', 'PuRd_r', 'Purples_r', 'RdBu_r', 'RdGy_r', 'RdPu_r', 'RdYlBu_r', 'RdYlGn_r', 'Reds_r', 'Spectral_r', 'Wistia_r', 'YlGn_r', 'YlGnBu_r', 'YlOrBr_r', 'YlOrRd_r', 'afmhot_r', 'autumn_r', 'binary_r', 'bone_r', 'brg_r', 'bwr_r', 'cool_r', 'coolwarm_r', 'copper_r', 'cubehelix_r', 'flag_r', 'gist_earth_r', 'gist_gray_r', 'gist_heat_r', 'gist_ncar_r', 'gist_rainbow_r', 'gist_stern_r', 'gist_yarg_r', 'gnuplot_r', 'gnuplot2_r', 'gray_r', 'hot_r', 'hsv_r', 'jet_r', 'nipy_spectral_r', 'ocean_r', 'pink_r', 'prism_r', 'rainbow_r', 'seismic_r', 'spring_r', 'summer_r', 'terrain_r', 'winter_r', 'Accent_r', 'Dark2_r', 'Paired_r', 'Pastel1_r', 'Pastel2_r', 'Set1_r', 'Set2_r', 'Set3_r', 'tab10_r', 'tab20_r', 'tab20b_r', 'tab20c_r']

# %%
import random
gdf = gpd.read_file("./data/stlucia.geojson")
gdf['Amount'] = gdf.apply(lambda row: random.randint(50,500), axis=1)
gdf
# Out:
#                     source    id          name  \
# 0   https://simplemaps.com  LC06    Gros Islet
# 1   https://simplemaps.com  LC02      Castries
# 2   https://simplemaps.com  LC01  Anse-la-Raye
# 3   https://simplemaps.com  LC10     Soufrière
# 4   https://simplemaps.com  LC03      Choiseul
# 5   https://simplemaps.com  LC07       Laborie
# 6   https://simplemaps.com  LC11    Vieux Fort
# 7   https://simplemaps.com  LC08        Micoud
# 8   https://simplemaps.com  LC09       Praslin
# 9   https://simplemaps.com  LC05       Dennery
# 10  https://simplemaps.com  LC04       Dauphin
#
#                                              geometry  Amount
# 0   POLYGON ((-60.97997 14.04352, -60.97606 14.061...     344
# 1   POLYGON ((-60.97997 14.04352, -60.96559 14.034...     155
# 2   POLYGON ((-61.0266 13.98737, -61.00945 13.9817...     237
# 3   POLYGON ((-60.98063 13.8928, -60.97185 13.8827...     211
# 4   POLYGON ((-61.0681 13.79218, -61.04956 13.8063...     366
# 5   POLYGON ((-61.01892 13.75625, -61.01203 13.770...     445
# 6   POLYGON ((-60.98158 13.83577, -60.97522 13.839...     381
# 7   POLYGON ((-60.97522 13.83923, -60.96433 13.845...     475
# 8   POLYGON ((-60.96057 13.87901, -60.96057 13.900...     419
# 9   POLYGON ((-60.96057 13.90032, -60.95681 13.927...     224
# 10  POLYGON ((-60.93559 14.01796, -60.933 14.03692...      97

# %%
gdf.explore(column='Amount', cmap='inferno')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ff11e2a78e39ef18d01ef5ec85d57a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ff11e2a78e39ef18d01ef5ec85d57a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ff11e2a78e39ef18d01ef5ec85d57a2 = L.map(
#                 &quot;map_7ff11e2a78e39ef18d01ef5ec85d57a2&quot;,
#                 {
#                     center: [13.913275584714711, -60.98074296702212],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7ff11e2a78e39ef18d01ef5ec85d57a2);
#
#
#
#
#
#             var tile_layer_c09337bb2d4b26b017512aada08eeab3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c09337bb2d4b26b017512aada08eeab3.addTo(map_7ff11e2a78e39ef18d01ef5ec85d57a2);
#
#
#             map_7ff11e2a78e39ef18d01ef5ec85d57a2.fitBounds(
#                 [[13.714667199671691, -61.07852128744509], [14.111883969757729, -60.88296464659914]],
#                 {}
#             );
#
#
#         function geo_json_4698b65e8607f59d0339879d446cedca_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#eb6429&quot;, &quot;fillColor&quot;: &quot;#eb6429&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#2d0b59&quot;, &quot;fillColor&quot;: &quot;#2d0b59&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#87216b&quot;, &quot;fillColor&quot;: &quot;#87216b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#6c186e&quot;, &quot;fillColor&quot;: &quot;#6c186e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#f57d15&quot;, &quot;fillColor&quot;: &quot;#f57d15&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#f4e156&quot;, &quot;fillColor&quot;: &quot;#f4e156&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#f98e09&quot;, &quot;fillColor&quot;: &quot;#f98e09&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#fcffa4&quot;, &quot;fillColor&quot;: &quot;#fcffa4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fac026&quot;, &quot;fillColor&quot;: &quot;#fac026&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#000004&quot;, &quot;fillColor&quot;: &quot;#000004&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#7a1d6d&quot;, &quot;fillColor&quot;: &quot;#7a1d6d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4698b65e8607f59d0339879d446cedca_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4698b65e8607f59d0339879d446cedca_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = g

# %% [markdown]
# ###  Geopandas Choropleth Maps in streamlit.
#
# If you plan to use `GeoDataFrame.explore()` then you will need to call `folium_static()` from the `streamlit_folium` module to display the map in Streamlit.
#
#
# `6-3-geopandas-px-mapbox.py`

# %% [markdown]
# ## Challenge 6-3-2
#
# Plot the following data as a choropleth map:
#
# `https://raw.githubusercontent.com/wrobstory/vincent/master/examples/data/US_Unemployment_Oct2012.csv`
#
# 1. load the data into pandas
# 2. load the geometry data into geopandas (in the data folder)
# 3. merge the data on a common key
# 4. explore in geopandas!
